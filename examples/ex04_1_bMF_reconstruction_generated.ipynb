# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append('../')

from models import bMFThreshold, bMFPenalty
import pandas as pd

# %% [markdown]
# ### Generate Boolean matrix

# %%
# generate arbitrary Boolean matrix (X)

from generators import DiagBooleanMatrix, ArbiBooleanMatrix

n_row=1000
n_col=500
k=5
overlap_flag=True
noise=[0.4, 0.02]
size_range=[0.25, 0.75, 0.25, 1.0]

X = ArbiBooleanMatrix(m=n_row, n=n_col, k=k, overlap_flag=False, size_range=size_range)
X.generate(seed=1234) # if no seed assigned, use time instead
X.add_noise(noise=noise, seed=1024)
X.show_matrix(scaling=0.2, title='arbitrary boolean matrix X')
# Out:
# [I] m            : 1000
# [I] n            : 500
# [I] k            : 5
# [I] overlap_flag : False
# [I] size_range   : [0.25 0.75 0.25 1.  ]
# [I] seed         : 1234
# [I] noise        : [0.4  0.02]
# [I] seed         : 1024
# [I] Using RandomState.

# %% [markdown]
# ## I. Reconstruction task

# %%
from datasets import NoSplit

X_split = NoSplit(X=X.X)

X_train, X_val, X_test = X_split.X_train, X_split.X_val, X_split.X_test

# %% [markdown]
# ### 1. Manually select tau
# k and w are not effective here.

# %%
k = 5
rho = 1
w = [1, 1]

bmf = bMFPenalty(k=k)
bmf.fit(X_train, display=True, scaling=1.0, verbose=True)

# from utils import matmul, to_dense, show_matrix
# settings = [(to_dense(X_test), [0, 0], 'X'), 
#             (matmul(panda.U, panda.V.T, sparse=False, boolean=True), [0, 1], "X'")]
# show_matrix(settings=settings, scaling=0.5)
# Out:
# [I] k            : 5
# [I] algorithm    : penalty
# [I] reg          : 10
# [I] reg_growth   : 10
# [I] eps          : 0.01
# [I] max_iter     : 100
# [I] verbose      : True
# [I] display      : True
# [I]   scaling    : 1.0
# [W] Missing validation data.
# [I] k            : 5
# [I] seed         : 1702405866
# [I] init         : random
# [I] max_iter     : 2000
# [W] Missing validation data.
# [I] After initialization: max U: 1.758, max V: 0.730
# c:\Users\nieht\Anaconda3\envs\cornac\lib\site-packages\scipy\sparse\_compressed.py:291: SparseEfficiencyWarning: Comparing a sparse matrix with a scalar greater than zero using < is inefficient, try using >= instead.
#   warn(bad_scalar_msg, SparseEfficiencyWarning)
# c:\Users\nieht\Anaconda3\envs\cornac\lib\site-packages\scipy\sparse\_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# [I] After normalization: max U: 0.971, max V: 0.730
# [I] iter: 0, reg: 10.000, err: 41.475, rec_err: 17881.762, reg_err: 41.475
# [I] iter: 1, reg: 100.000, err: 33.066, rec_err: 16286.935, reg_err: 33.066
# [I] iter: 2, reg: 1000.000, err: 26.465, rec_err: 16392.654, reg_err: 26.465
# [I] iter: 3, reg: 10000.000, err: 20.626, rec_err: 16699.366, reg_err: 20.626
# [I] iter: 4, reg: 100000.000, err: 15.927, rec_err: 17069.717, reg_err: 15.927
# [I] iter: 5, reg: 1000000.000, err: 12.042, rec_err: 17525.804, reg_err: 12.042
# [I] iter: 6, reg: 10000000.000, err: 8.947, rec_err: 18050.927, reg_err: 8.947
# [I] iter: 7, reg: 100000000.000, err: 6.544, rec_err: 18602.621, reg_err: 6.544
# [I] iter: 8, reg: 1000000000.000, err: 4.713, rec_err: 19143.195, reg_err: 4.713
# [I] iter: 9, reg: 10000000000.000, err: 3.345, rec_err: 19648.192, reg_err: 3.345
# c:\Users\nieht\Anaconda3\envs\cornac\lib\site-packages\scipy\sparse\_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csc_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# [I] iter: 10, reg: 100000000000.000, err: 2.374, rec_err: 20097.242, reg_err: 2.374
# [I] iter: 11, reg: 1000000000000.000, err: 1.703, rec_err: 20469.036, reg_err: 1.703
# [I] iter: 12, reg: 10000000000000.000, err: 1.227, rec_err: 20767.760, reg_err: 1.227
# [I] iter: 13, reg: 100000000000000.000, err: 0.893, rec_err: 21009.070, reg_err: 0.893
# [I] iter: 14, reg: 1000000000000000.000, err: 0.671, rec_err: 21198.783, reg_err: 0.671
# [I] iter: 15, reg: 10000000000000000.000, err: 0.515, rec_err: 21342.052, reg_err: 0.515
# [I] iter: 16, reg: 100000000000000000.000, err: 0.395, rec_err: 21453.650, reg_err: 0.395
# [I] iter: 17, reg: 1000000000000000000.000, err: 0.301, rec_err: 21541.885, reg_err: 0.301
# [I] iter: 18, reg: 10000000000000000000.000, err: 0.229, rec_err: 21609.551, reg_err: 0.229
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\nieht\Anaconda3\envs\cornac\lib\site-packages\scipy\sparse\_base.py:376, in spmatrix.asformat(self, format, copy)
#     375 try:
# --> 376     return convert_method(copy=copy)
#     377 except TypeError:
#
# File c:\Users\nieht\Anaconda3\envs\cornac\lib\site-packages\scipy\sparse\_csr.py:177, in csr_matrix.tocsc(self, copy)
#     176 indices = np.empty(self.nnz, dtype=idx_dtype)
# --> 177 data = np.empty(self.nnz, dtype=upcast(self.dtype))
#     179 csr_tocsc(self.shape[0], self.shape[1],
#     180           self.indptr.astype(idx_dtype),
#     181           self.indices.astype(idx_dtype),
#    (...)
#     184           indices,
#     185           data)
#
# File c:\Users\nieht\Anaconda3\envs\cornac\lib\site-packages\scipy\sparse\_sputils.py:51, in upcast(*args)
#      49         return t
# ---> 51 raise TypeError('no supported conversion for types: %r' % (args,))
#
# TypeError: no supported conversion for types: (dtype('O'),)
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# d:\Dropbox\PyBMF\examples\ex04_1_bMF_reconstruction_generated.ipynb Cell 7 line 6
#       <a href='vscode-notebook-cell:/d%3A/Dropbox/PyBMF/examples/ex04_1_bMF_reconstruction_generated.ipynb#W6sZmlsZQ%3D%3D?line=2'>3</a> w = [1, 1]
#       <a href='vscode-notebook-cell:/d%3A/Dropbox/PyBMF/examples/ex04_1_bMF_reconstruction_generated.ipynb#W6sZmlsZQ%3D%3D?line=4'>5</a> bmf = bMFPenalty(k=k)
# ----> <a href='vscode-notebook-cell:/d%3A/Dropbox/PyBMF/examples/ex04_1_bMF_reconstruction_generated.ipynb#W6sZmlsZQ%3D%3D?line=5'>6</a> bmf.fit(X_train, display=True, scaling=1.0, verbose=True)
#
# File d:\Dropbox\PyBMF\examples\..\models\bMF.py:29, in bMF.fit(self, X_train, X_val, **kwargs)
#      27 self.check_params(**kwargs)
#      28 self.check_dataset(X_train, X_val)
# ---> 29 self._fit()
#
# File d:\Dropbox\PyBMF\examples\..\models\bMFPenalty.py:20, in bMFPenalty._fit(self)
#      18 self.initialize()
#      19 self.normalize()
# ---> 20 self.penalty_algorithm()
#
# File d:\Dropbox\PyBMF\examples\..\models\bMFPenalty.py:44, in bMFPenalty.penalty_algorithm(self)
#      41     break
#      43 self.V = self.V.T
# ---> 44 self.penalty_update_V()
#      45 self.penalty_update_U()
#      46 self.V = self.V.T
#
# File d:\Dropbox\PyBMF\examples\..\models\bMFPenalty.py:81, in bMFPenalty.penalty_update_V(self)
#      75 def penalty_update_V(self):
#      76     '''Multiplicative update of V
#      77
#      78     U: (m, k)
#      79     V: (k, m)
#      80     '''
# ---> 81     numerator = self.U.T @ self.X_train + 3 * self.reg * self.V.power(2)
#      82     denominator = (self.U.T @ self.U) @ self.V + 2 * self.reg * self.V.power(3) + self.reg * self.V
#      83     denominator_size = denominator.shape[0] * denominator.shape[1]
#
# File c:\Users\nieht\Anaconda3\envs\cornac\lib\site-packages\scipy\sparse\_base.py:472, in spmatrix.__add__(self, other)
#     470     if other.shape != self.shape:
#     471         raise ValueError("inconsistent shapes")
# --> 472     return self._add_sparse(other)
#     473 elif isdense(other):
#     474     other = np.broadcast_to(other, self.shape)
#
# File c:\Users\nieht\Anaconda3\envs\cornac\lib\site-packages\scipy\sparse\_compressed.py:360, in _cs_matrix._add_sparse(self, other)
#     359 def _add_sparse(self, other):
# --> 360     return self._binopt(other, '_plus_')
#
# File c:\Users\nieht\Anaconda3\envs\cornac\lib\site-packages\scipy\sparse\_compressed.py:1240, in _cs_matrix._binopt(self, other, op)
#    1238 def _binopt(self, other, op):
#    1239     """apply the binary operation fn to two sparse matrices."""
# -> 1240     other = self.__class__(other)
#    1242     # e.g. csr_plus_csr, csr_minus_csr, etc.
#    1243     fn = getattr(_sparsetools, self.format + op + self.format)
#
# File c:\Users\nieht\Anaconda3\envs\cornac\lib\site-packages\scipy\sparse\_compressed.py:33, in _cs_matrix.__init__(self, arg1, shape, dtype, copy)
#      31         arg1 = arg1.copy()
#      32     else:
# ---> 33         arg1 = arg1.asformat(self.format)
#      34     self._set_self(arg1)
#      36 elif isinstance(arg1, tuple):
#
# File c:\Users\nieht\Anaconda3\envs\cornac\lib\site-packages\scipy\sparse\_base.py:378, in spmatrix.asformat(self, format, copy)
#     376     return convert_method(copy=copy)
#     377 except TypeError:
# --> 378     return convert_method()
#
# File c:\Users\nieht\Anaconda3\envs\cornac\lib\site-packages\scipy\sparse\_csr.py:177, in csr_matrix.tocsc(self, copy)
#     175 indptr = np.empty(self.shape[1] + 1, dtype=idx_dtype)
#     176 indices = np.empty(self.nnz, dtype=idx_dtype)
# --> 177 data = np.empty(self.nnz, dtype=upcast(self.dtype))
#     179 csr_tocsc(self.shape[0], self.shape[1],
#     180           self.indptr.astype(idx_dtype),
#     181           self.indices.astype(idx_dtype),
#    (...)
#     184           indices,
#     185           data)
#     187 A = self._csc_container((data, indices, indptr), shape=self.shape)
#
# File c:\Users\nieht\Anaconda3\envs\cornac\lib\site-packages\scipy\sparse\_sputils.py:51, in upcast(*args)
#      48         _upcast_memo[hash(args)] = t
#      49         return t
# ---> 51 raise TypeError('no supported conversion for types: %r' % (args,))
#
# TypeError: no supported conversion for types: (dtype('O'),)

# %%
k = 15
rho = 1.0
w = [1, 1]

panda = Panda(k=k, rho=rho, w=w)
panda.fit(X_train, verbose=False)

# from utils import matmul, to_dense, show_matrix
# settings = [(to_dense(X_test), [0, 0], 'X'), 
#             (matmul(panda.U, panda.V.T, sparse=False, boolean=True), [0, 1], "X'")]
# show_matrix(settings=settings, scaling=0.5)
# Out:
# [I] k            : 15
# [I] rho          : 1.0
# [I] weights      : [1, 1]
# [W] Missing validation data.
# pattern 3472
# pattern 11592
# pattern 100
# pattern 99
# pattern 6580
# pattern 84
# pattern 3700
# pattern 5832
# pattern 5320
# pattern 60
# pattern 58
# pattern 51
# pattern 50
# pattern 49
# pattern 43

# %% [markdown]
# ### 2. Grid search for w
# Use some small k and selected tau for trials.

# %%
k = 5
tau = 0.30
w_list = [[0.4, 0.6], [0.5, 0.5], [0.6, 0.4], [0.7, 0.3], [0.8, 0.2], [0.9, 0.1]]

# empty table
from utils import add_log

# metrics from sklearn is included for checking
metrics = ['Recall', 'Precision', 'Error', 'Accuracy', 'F1', 'recall_score', 'precision_score', 'accuracy_score', 'f1_score']
columns = ['time', 'k', 'tau', 'p_pos', 'p_neg'] + metrics
df_prediction = pd.DataFrame(columns=columns)
df_reconstruction = pd.DataFrame(columns=columns)

# %%
for w in w_list:
    asso = Asso(k=k, tau=tau, w=w)
    asso.fit(X_train, display=True, scaling=0.3)

    results = asso.eval(X_val, metrics=metrics, task='reconstruction')
    add_log(df_reconstruction, [pd.Timestamp.now(), k, tau, w[0], w[1]] + results, verbose=True)

    # to see the difference of 'prediction' and 'reconstruction'
    # here X_val is same as X_train. it's not a good practice to use prediction in reconstruction tasks.
    # since there is no negative samples, precision will always be 1.0.
    results = asso.eval(X_val, metrics=metrics, task='prediction')
    add_log(df_prediction, [pd.Timestamp.now(), k, tau, w[0], w[1]] + results, verbose=True)
# Out:
# [I] k            : 5
# [I] tau          : 0.3
# [I] weights      : [0.4, 0.6]
# [W] Missing validation data.
# [I] display      : True
# [I]   scaling    : 0.3
# 100%|██████████| 5/5 [00:23<00:00,  4.68s/it]
# [I] task         : reconstruction
#                         time  k  tau  p_pos  p_neg    Recall  Precsion  \
# 0 2023-12-08 04:11:01.777041  5  0.3    0.4    0.6  0.414874   0.64855
#
#       Error  Accuracy        F1  recall_score  precision_score  \
# 0  0.045566  0.954434  0.506038      0.414874          0.64855
#
#    accuracy_score  f1_score
# 0        0.954434  0.506038
# [I] task         : prediction
#                         time  k  tau  p_pos  p_neg    Recall  Precsion  \
# 0 2023-12-08 04:11:12.293833  5  0.3    0.4    0.6  0.414874       1.0
#
#       Error  Accuracy        F1  recall_score  precision_score  \
# 0  0.585126  0.414874  0.586447      0.414874              1.0
#
#    accuracy_score  f1_score
# 0        0.414874  0.586447
# [I] k            : 5
# [I] tau          : 0.3
# [I] weights      : [0.5, 0.5]
# [W] Missing validation data.
# [I] display      : True
# [I]   scaling    : 0.3
# 100%|██████████| 5/5 [00:24<00:00,  4.87s/it]
# [I] task         : reconstruction
#                         time  k  tau  p_pos  p_neg    Recall  Precsion  \
# 0 2023-12-08 04:11:01.777041  5  0.3    0.4    0.6  0.414874  0.648550
# 1 2023-12-08 04:11:37.706239  5  0.3    0.5    0.5  0.640442  0.612068
#
#       Error  Accuracy        F1  recall_score  precision_score  \
# 0  0.045566  0.954434  0.506038      0.414874         0.648550
# 1  0.043064  0.956936  0.625934      0.640442         0.612068
#
#    accuracy_score  f1_score
# 0        0.954434  0.506038
# 1        0.956936  0.625934
# [I] task         : prediction
#                         time  k  tau  p_pos  p_neg    Recall  Precsion  \
# 0 2023-12-08 04:11:12.293833  5  0.3    0.4    0.6  0.414874       1.0
# 1 2023-12-08 04:11:48.214716  5  0.3    0.5    0.5  0.640442       1.0
#
#       Error  Accuracy        F1  recall_score  precision_score  \
# 0  0.585126  0.414874  0.586447      0.414874              1.0
# 1  0.359558  0.640442  0.780817      0.640442              1.0
#
#    accuracy_score  f1_score
# 0        0.414874  0.586447
# 1        0.640442  0.780817
# [I] k            : 5
# [I] tau          : 0.3
# [I] weights      : [0.6, 0.4]
# [W] Missing validation data.
# [I] display      : True
# [I]   scaling    : 0.3
# 100%|██████████| 5/5 [00:24<00:00,  4.92s/it]
# [I] task         : reconstruction
#                         time  k  tau  p_pos  p_neg    Recall  Precsion  \
# 0 2023-12-08 04:11:01.777041  5  0.3    0.4    0.6  0.414874  0.648550
# 1 2023-12-08 04:11:37.706239  5  0.3    0.5    0.5  0.640442  0.612068
# 2 2023-12-08 04:12:13.874046  5  0.3    0.6    0.4  0.664830  0.599545
#
#       Error  Accuracy        F1  recall_score  precision_score  \
# 0  0.045566  0.954434  0.506038      0.414874         0.648550
# 1  0.043064  0.956936  0.625934      0.640442         0.612068
# 2  0.043838  0.956162  0.630502      0.664830         0.599545
#
#    accuracy_score  f1_score
# 0        0.954434  0.506038
# 1        0.956936  0.625934
# 2        0.956162  0.630502
# [I] task         : prediction
#                         time  k  tau  p_pos  p_neg    Recall  Precsion  \
# 0 2023-12-08 04:11:12.293833  5  0.3    0.4    0.6  0.414874       1.0
# 1 2023-12-08 04:11:48.214716  5  0.3    0.5    0.5  0.640442       1.0
# 2 2023-12-08 04:12:24.938715  5  0.3    0.6    0.4  0.664830       1.0
#
#       Error  Accuracy        F1  recall_score  precision_score  \
# 0  0.585126  0.414874  0.586447      0.414874              1.0
# 1  0.359558  0.640442  0.780817      0.640442              1.0
# 2  0.335170  0.664830  0.798676      0.664830              1.0
#
#    accuracy_score  f1_score
# 0        0.414874  0.586447
# 1        0.640442  0.780817
# 2        0.664830  0.798676
# [I] k            : 5
# [I] tau          : 0.3
# [I] weights      : [0.7, 0.3]
# [W] Missing validation data.
# [I] display      : True
# [I]   scaling    : 0.3
# 100%|██████████| 5/5 [00:26<00:00,  5.32s/it]
# [I] task         : reconstruction
#                         time  k  tau  p_pos  p_neg    Recall  Precsion  \
# 0 2023-12-08 04:11:01.777041  5  0.3    0.4    0.6  0.414874  0.648550
# 1 2023-12-08 04:11:37.706239  5  0.3    0.5    0.5  0.640442  0.612068
# 2 2023-12-08 04:12:13.874046  5  0.3    0.6    0.4  0.664830  0.599545
# 3 2023-12-08 04:12:52.626627  5  0.3    0.7    0.3  0.669274  0.589491
#
#       Error  Accuracy        F1  recall_score  precision_score  \
# 0  0.045566  0.954434  0.506038      0.414874         0.648550
# 1  0.043064  0.956936  0.625934      0.640442         0.612068
# 2  0.043838  0.956162  0.630502      0.664830         0.599545
# 3  0.044826  0.955174  0.626854      0.669274         0.589491
#
#    accuracy_score  f1_score
# 0        0.954434  0.506038
# 1        0.956936  0.625934
# 2        0.956162  0.630502
# 3        0.955174  0.626854
# [I] task         : prediction
#                         time  k  tau  p_pos  p_neg    Recall  Precsion  \
# 0 2023-12-08 04:11:12.293833  5  0.3    0.4    0.6  0.414874       1.0
# 1 2023-12-08 04:11:48.214716  5  0.3    0.5    0.5  0.640442       1.0
# 2 2023-12-08 04:12:24.938715  5  0.3    0.6    0.4  0.664830       1.0
# 3 2023-12-08 04:13:03.202594  5  0.3    0.7    0.3  0.669274       1.0
#
#       Error  Accuracy        F1  recall_score  precision_score  \
# 0  0.585126  0.414874  0.586447      0.414874              1.0
# 1  0.359558  0.640442  0.780817      0.640442              1.0
# 2  0.335170  0.664830  0.798676      0.664830              1.0
# 3  0.330726  0.669274  0.801874      0.669274              1.0
#
#    accuracy_score  f1_score
# 0        0.414874  0.586447
# 1        0.640442  0.780817
# 2        0.664830  0.798676
# 3        0.669274  0.801874
# [I] k            : 5
# [I] tau          : 0.3
# [I] weights      : [0.8, 0.2]
# [W] Missing validation data.
# [I] display      : True
# [I]   scaling    : 0.3
# 100%|██████████| 5/5 [00:24<00:00,  4.93s/it]
# [I] task         : reconstruction
#                         time  k  tau  p_pos  p_neg    Recall  Precsion  \
# 0 2023-12-08 04:11:01.777041  5  0.3    0.4    0.6  0.414874  0.648550
# 1 2023-12-08 04:11:37.706239  5  0.3    0.5    0.5  0.640442  0.612068
# 2 2023-12-08 04:12:13.874046  5  0.3    0.6    0.4  0.664830  0.599545
# 3 2023-12-08 04:12:52.626627  5  0.3    0.7    0.3  0.669274  0.589491
# 4 2023-12-08 04:13:29.037089  5  0.3    0.8    0.2  0.669274  0.589491
#
#       Error  Accuracy        F1  recall_score  precision_score  \
# 0  0.045566  0.954434  0.506038      0.414874         0.648550
# 1  0.043064  0.956936  0.625934      0.640442         0.612068
# 2  0.043838  0.956162  0.630502      0.664830         0.599545
# 3  0.044826  0.955174  0.626854      0.669274         0.589491
# 4  0.044826  0.955174  0.626854      0.669274         0.589491
#
#    accuracy_score  f1_score
# 0        0.954434  0.506038
# 1        0.956936  0.625934
# 2        0.956162  0.630502
# 3        0.955174  0.626854
# 4        0.955174  0.626854
# [I] task         : prediction
#                         time  k  tau  p_pos  p_neg    Recall  Precsion  \
# 0 2023-12-08 04:11:12.293833  5  0.3    0.4    0.6  0.414874       1.0
# 1 2023-12-08 04:11:48.214716  5  0.3    0.5    0.5  0.640442       1.0
# 2 2023-12-08 04:12:24.938715  5  0.3    0.6    0.4  0.664830       1.0
# 3 2023-12-08 04:13:03.202594  5  0.3    0.7    0.3  0.669274       1.0
# 4 2023-12-08 04:13:39.415041  5  0.3    0.8    0.2  0.669274       1.0
#
#       Error  Accuracy        F1  recall_score  precision_score  \
# 0  0.585126  0.414874  0.586447      0.414874              1.0
# 1  0.359558  0.640442  0.780817      0.640442              1.0
# 2  0.335170  0.664830  0.798676      0.664830              1.0
# 3  0.330726  0.669274  0.801874      0.669274              1.0
# 4  0.330726  0.669274  0.801874      0.669274              1.0
#
#    accuracy_score  f1_score
# 0        0.414874  0.586447
# 1        0.640442  0.780817
# 2        0.664830  0.798676
# 3        0.669274  0.801874
# 4        0.669274  0.801874
# [I] k            : 5
# [I] tau          : 0.3
# [I] weights      : [0.9, 0.1]
# [W] Missing validation data.
# [I] display      : True
# [I]   scaling    : 0.3
# 100%|██████████| 5/5 [00:25<00:00,  5.01s/it]
# [I] task         : reconstruction
#                         time  k  tau  p_pos  p_neg    Recall  Precsion  \
# 1 2023-12-08 04:11:37.706239  5  0.3    0.5    0.5  0.640442  0.612068
# 2 2023-12-08 04:12:13.874046  5  0.3    0.6    0.4  0.664830  0.599545
# 3 2023-12-08 04:12:52.626627  5  0.3    0.7    0.3  0.669274  0.589491
# 4 2023-12-08 04:13:29.037089  5  0.3    0.8    0.2  0.669274  0.589491
# 5 2023-12-08 04:14:05.526193  5  0.3    0.9    0.1  0.674286  0.519886
#
#       Error  Accuracy        F1  recall_score  precision_score  \
# 1  0.043064  0.956936  0.625934      0.640442         0.612068
# 2  0.043838  0.956162  0.630502      0.664830         0.599545
# 3  0.044826  0.955174  0.626854      0.669274         0.589491
# 4  0.044826  0.955174  0.626854      0.669274         0.589491
# 5  0.053356  0.946644  0.587105      0.674286         0.519886
#
#    accuracy_score  f1_score
# 1        0.956936  0.625934
# 2        0.956162  0.630502
# 3        0.955174  0.626854
# 4        0.955174  0.626854
# 5        0.946644  0.587105
# [I] task         : prediction
#                         time  k  tau  p_pos  p_neg    Recall  Precsion  \
# 1 2023-12-08 04:11:48.214716  5  0.3    0.5    0.5  0.640442       1.0
# 2 2023-12-08 04:12:24.938715  5  0.3    0.6    0.4  0.664830       1.0
# 3 2023-12-08 04:13:03.202594  5  0.3    0.7    0.3  0.669274       1.0
# 4 2023-12-08 04:13:39.415041  5  0.3    0.8    0.2  0.669274       1.0
# 5 2023-12-08 04:14:16.516336  5  0.3    0.9    0.1  0.674286       1.0
#
#       Error  Accuracy        F1  recall_score  precision_score  \
# 1  0.359558  0.640442  0.780817      0.640442              1.0
# 2  0.335170  0.664830  0.798676      0.664830              1.0
# 3  0.330726  0.669274  0.801874      0.669274              1.0
# 4  0.330726  0.669274  0.801874      0.669274              1.0
# 5  0.325714  0.674286  0.805461      0.674286              1.0
#
#    accuracy_score  f1_score
# 1        0.640442  0.780817
# 2        0.664830  0.798676
# 3        0.669274  0.801874
# 4        0.669274  0.801874
# 5        0.674286  0.805461

# %% [markdown]
# ### 3. Get k
# Given tau and w.

# %%
k = 10 # more than ground truth k
tau = 0.30
w = [0.75, 0.25]

asso = Asso(k=k, tau=tau, w=w)
asso.fit(X_train, X_val, task='reconstruction') # assign X_val and task to activate per-step eval

display(asso.df_validation)
# Out:
# [I] k            : 10
# [I] tau          : 0.3
# [I] weights      : [0.75, 0.25]
# [I] task         : reconstruction
# 100%|██████████| 10/10 [00:52<00:00,  5.23s/it]
#                         time   k  tau  p_pos  p_neg    Recall  Precsion  \
# 0 2023-12-08 04:24:03.675511   1  0.3   0.75   0.25  0.315404  0.575506
# 1 2023-12-08 04:24:08.742658   2  0.3   0.75   0.25  0.467489  0.582632
# 2 2023-12-08 04:24:14.214632   3  0.3   0.75   0.25  0.584770  0.586584
# 3 2023-12-08 04:24:19.555170   4  0.3   0.75   0.25  0.666394  0.589169
# 4 2023-12-08 04:24:24.889271   5  0.3   0.75   0.25  0.669274  0.589491
# 5 2023-12-08 04:24:30.152316   6  0.3   0.75   0.25  0.670945  0.589431
# 6 2023-12-08 04:24:35.476917   7  0.3   0.75   0.25  0.672153  0.589867
# 7 2023-12-08 04:24:40.761179   8  0.3   0.75   0.25  0.673789  0.589793
# 8 2023-12-08 04:24:46.139872   9  0.3   0.75   0.25  0.675282  0.589760
# 9 2023-12-08 04:24:51.499591  10  0.3   0.75   0.25  0.676810  0.589649
#
#    Accuracy        F1
# 0  0.948398  0.407487
# 1  0.951202  0.518748
# 2  0.953454  0.585676
# 3  0.955090  0.625407
# 4  0.955174  0.626854
# 5  0.955196  0.627552
# 6  0.955264  0.628327
# 7  0.955284  0.628999
# 8  0.955306  0.629630
# 9  0.955320  0.630230

# %% [markdown]
# ### 4. Reconstruct using given k, tau, w

# %%
k = 5
tau = 0.30
w = [0.75, 0.25]

asso = Asso(k=k, tau=tau, w=w)
asso.fit(X_train) # assign X_val and task to activate per-step eval
# Out:
# [I] k            : 5
# [I] tau          : 0.3
# [I] weights      : [0.75, 0.25]
# [W] Missing validation data.
# 100%|██████████| 5/5 [00:25<00:00,  5.04s/it]

# %%
from utils import matmul, to_dense, show_matrix
settings = [(to_dense(X_test), [0, 0], 'X'), 
            (matmul(panda.U, panda.V.T, sparse=False, boolean=True), [0, 1], "X'")]
show_matrix(settings=settings)
